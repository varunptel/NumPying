# %% [markdown]
# # RANDOM NUMBERS IN NUMPY
#
# There are no true numbers in computer language as everything is just a set of instruction. So the random numbers generated by NumPy is just a deterministic algorithms. Therefore they are called pseudo-random numbers.
#
# NumPy has built-in module numpy.random which is fast, vectorized and supports a lot of probability distributions.
#
# The numpy.random module supplements the built-in Python random module with
# functions for efficiently generating whole arrays of sample values from many kinds of probability distributions.
#
#
# | Method | Description |
# | :--- | :--- |
# | `permutation` | Return a random permutation of a sequence, or return a permuted range. |
# | `shuffle` | Randomly permute a sequence in place. |
# | `uniform` | Draw samples from a uniform distribution (specify range). |
# | `integers` | Draw random integers from a given low-to-high range. |
# | `standard_normal` | Draw samples from a normal distribution with mean 0 and standard deviation 1. |
# | `binomial` | Draw samples from a binomial distribution. |
# | `normal` | Draw samples from a normal (Gaussian) distribution. |
# | `beta` | Draw samples from a beta distribution. |
# | `chisquare` | Draw samples from a chi-square distribution. |
# | `gamma` | Draw samples from a gamma distribution. |
# | `random` | Draw samples from a uniform [0, 1) distribution. |

# %% [markdown]
# ## Generate Random Numbers:

# %%
from numpy import random

x = random.randint(5) #integers
y = random.rand()   #random float

print(x)
print(y)
# Out:
# 0
# 0.028053169279874002

# %%
# Generate random array

x = random.randint(50, size = (5)) #Integers 1-D. Change the size to (a,b) for 2D and so on.
y = random.rand(5) #1D float number random numbers array. (a,b) for 2D and so one.

print(x)
print(y)
# Out:
# [ 0  8 18 29 28]
# [0.71949368 0.9859745  0.67971794 0.2943545  0.74596475]

# %%
# To choose a random value from the array we can use choice() function from the random functions.

x = random.choice([35,69,45,55,56,78,3,55,2,66,0])

y = random.choice([35,69,45,55,56,78,3,55,2,66,0], size = (3,5)) #returns the array of size 3*5 from the array
print(x)
print(y)
# Out:
# 2
# [[35 69 56 45 35]
#  [78 78  0  0 45]
#  [66  3  0 35 56]]

# %%
# Shuffling ararays

import numpy as np

arr = np.array([1,2,3,4,5,6])

np.random.shuffle(arr)
# Shuffle method make change to the original arrays.
print(arr)
# Out:
# [3 1 6 2 4 5]

# %%
# Permutations of arrays

arr = np.array([1,2,3,4,5,6])

print(np.random.permutation(arr))  # Permutation function doesn't change the original array
print(arr)
# Out:
# [5 3 1 2 6 4]
# [1 2 3 4 5 6]

# %% [markdown]
# ### Modern Generator vs the Legacy interface
#
# There are number of reason to switch from the legacy interface (the old np.random.rand(), np.random.randn(), np.random.seed(), etc) to modern generator(np.random.default_rng()):
#
# 1. It is Faster:
# It uses modern, high-performance bit generator by default.
#
# 2. More flexible
# - The Generator gives you way more control and features that the old API simply doesn’t have:
#
# - You can pick the exact algorithm you want.
#
# - Many more distributions and advanced sampling methods (e.g., multivariate_normal, hypergeometric, lognormal, etc.) that are either missing or less convenient in the legacy API.

# %%
# Comparison between old and new random generators.
import numpy as np
import timeit

rng = np.random.default_rng()          # modern
legacy = np.random                    # old

# Generate 10 million standard normal numbers
print("Modern Generator:", timeit.timeit(lambda: rng.standard_normal(10_000_000), number=3))
print("Legacy np.random :", timeit.timeit(lambda: legacy.randn(10_000_000), number=3))
# Out:
# Modern Generator: 0.8733992649999891
# Legacy np.random : 0.9236056590000317

# %%
import numpy as np

#creating a generator:
rng = np.random.default_rng(seed = 50) # seed argument is what determines the initial state of the generator

print(rng.random(5)) #Random float

print(rng.integers(low = 10, high = 50, size = (2,3)))  #Random Integer
# Out:
# [0.78742269 0.83366933 0.54790446 0.9734491  0.23683356]
# [[21 35 36]
#  [12 48 32]]

# %% [markdown]
# ## Random Data Distribution:
#
# It means generating arrays of random numbers that follows specific probability distribution.
#
# It is best practice to use it so that we can create data that behaves like real-world phenomena.
#
# There are number of reasons to use it:
# - Real data rarely follows uniform distribution
# - Testing algorithms under realistic conditions
# - Generate training data, initialize weights, run hypothesis tests and so on.

# %%
import numpy as np
import matplotlib.pyplot as plt

rng = np.random.default_rng(seed = 40)
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.normal.html
data = rng.normal(loc=0, scale=1, size= 1000 * 1000)

plt.hist(data, bins = 50, density = True, alpha = 0.7)  #plot histogram with 50boxes
plt.show()

# %%
import numpy as np
my_arr = np.arange(1_000_000)
my_list = list(range(1_000_000))

# %timeit my_arr2 = my_arr * 2

# %timeit my_list2 = my_list * 2
# Out:
# 1.83 ms ± 751 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 16.4 ms ± 1.65 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# # Universal Functions: Fast Element-Wise Array Functions
#
# *  Some unary universal functions
#
#
# | Function | Description |
# | :--- | :--- |
# | `abs`, `fabs` | Compute absolute value element-wise for integer, floating-point, or complex values |
# | `sqrt` | Compute the square root of each element (equivalent to `arr ** 0.5`) |
# | `square` | Compute the square of each element (equivalent to `arr ** 2`) |
# | `exp` | Compute the exponent $e^x$ of each element |
# | `log`, `log10`, `log2`, `log1p` | Natural log (base $e$), log10, log2, and log(1 + x) |
# | `sign` | Compute the sign: 1 (positive), 0 (zero), or –1 (negative) |
# | `ceil` | Compute the ceiling of each element |
# | `floor` | Compute the floor of each element |
# | `rint` | Round elements to the nearest integer, preserving the dtype |
# | `modf` | Return fractional and integral parts of array as separate arrays |
# | `isnan` | Return Boolean array indicating whether each value is NaN |
# | `isfinite`, `isinf` | Return Boolean array indicating if each element is finite or infinite |
# | `cos`, `cosh`, `sin`, `sinh`, `tan`, `tanh` | Regular and hyperbolic trigonometric functions |
# | `arccos`, `arcsin`, `arctan`, etc. | Inverse trigonometric functions |
# | `logical_not` | Compute truth value of `not x` element-wise (equivalent to `~arr`) |
#
# * ufunc can return sometimes the multiple arrays for example numpy.modf returns the fractional and integral parts of a floating-point array.

# %% [markdown]
# * Some binary universal functions
#
#
#
# | Function | Description |
# | :--- | :--- |
# | `add` | Add corresponding elements in arrays |
# | `subtract` | Subtract elements in second array from first array |
# | `multiply` | Multiply array elements |
# | `divide`, `floor_divide` | Divide or floor divide (truncating the remainder) |
# | `power` | Raise elements in first array to powers indicated in second array |
# | `maximum`, `fmax` | Element-wise maximum; `fmax` ignores NaN |
# | `minimum`, `fmin` | Element-wise minimum; `fmin` ignores NaN |
# | `mod` | Element-wise modulus (remainder of division) |
# | `copysign` | Copy sign of values in second argument to values in first argument |
# | `greater`, `greater_equal`, `less`, `less_equal`, `equal`, `not_equal` | Perform element-wise comparison (equivalent to `>`, `>=`, `<`, `<=`, `==`, `!=`) |
# | `logical_and` | Compute element-wise truth value of AND (`&`) |
# | `logical_or` | Compute element-wise truth value of OR (`|`) |
# | `logical_xor` | Compute element-wise truth value of XOR (`^`) |

# %%
import numpy as np

arr = np.arange(10)

# %%
np.sqrt(arr)
# Out:
# array([0.        , 1.        , 1.41421356, 1.73205081, 2.        ,
#        2.23606798, 2.44948974, 2.64575131, 2.82842712, 3.        ])

# %%
np.exp(arr)
# Out:
# array([1.00000000e+00, 2.71828183e+00, 7.38905610e+00, 2.00855369e+01,
#        5.45981500e+01, 1.48413159e+02, 4.03428793e+02, 1.09663316e+03,
#        2.98095799e+03, 8.10308393e+03])

# %%
rng = np.random.default_rng(seed = 50)
x = rng.standard_normal(8)

print(x)

y = rng.standard_normal(8)
print(y)
# Out:
# [ 0.4863814  -0.47739198  0.66933962 -1.38729454  1.66588843 -0.19093152
#   0.53434886  0.77655179]
# [ 2.44750368e-01  1.79810422e-01 -1.34158469e+00 -1.81981247e-01
#  -5.42160868e-01  1.97963483e-03 -2.69980913e+00 -1.55722607e+00]

# %%
np.maximum(x, y)
# Out:
# array([ 0.4863814 ,  0.17981042,  0.66933962, -0.18198125,  1.66588843,
#         0.00197963,  0.53434886,  0.77655179])

# %%
arr = rng.standard_normal(7) * 5
arr
# Out:
# array([ -1.46396314,   1.2953169 ,  -1.00544411,  -5.50749526,
#         -2.96416826,  -2.14503676, -15.28854324])

# %%
remainder, whole_part = np.modf(arr)
print(remainder)
print(whole_part)
# Out:
# [-0.46396314  0.2953169  -0.00544411 -0.50749526 -0.96416826 -0.14503676
#  -0.28854324]
# [ -1.   1.  -1.  -5.  -2.  -2. -15.]

# %%
out = np.zeros_like(arr)

# %%
np.add(arr, 1)
# Out:
# array([-4.63963138e-01,  2.29531690e+00, -5.44410753e-03, -4.50749526e+00,
#        -1.96416826e+00, -1.14503676e+00, -1.42885432e+01])

# %%
np.add(arr, 1, out = out)
# Out:
# array([-4.63963138e-01,  2.29531690e+00, -5.44410753e-03, -4.50749526e+00,
#        -1.96416826e+00, -1.14503676e+00, -1.42885432e+01])

# %%
out
# Out:
# array([-4.63963138e-01,  2.29531690e+00, -5.44410753e-03, -4.50749526e+00,
#        -1.96416826e+00, -1.14503676e+00, -1.42885432e+01])

# %% [markdown]
# # Array-Oriented Programming with Arrays
#
# * Instead of writing Python looks, Numpy enables us to perform many kinds of data processing tasks faster, this sometimes referred as *vectorization*.
# * When you write a for loop in Python, the interpreter has to perform type checking and function overhead for every single iteration. With vectorization, the operation is pushed down to the underlying C and Fortran implementation, allowing the CPU to execute the task using SIMD (Single Instruction, Multiple Data) instructions.
#
#
# ### Key Techniques for Vectorization
#
# * *Broadcasting*: Broadcasting allows NumPy to perform arithmetic operations on arrays of different shapes.
# * * Example: Adding 10 to every element in a 2x3 array happens automatically without a loop.
#
# * *Universal Functions (ufuncs)*: These are functions that operate on NumPy arrays element-by-element.
#
# * *Boolean Masking (Filtering)*: Instead of using an if statement inside a loop to filter data, you can create a boolean mask.
# ```python
# # Instead of: [x for x in data if x > 5]
# filtered_data = data[data > 5]
# ```

# %%
import numpy as np
import matplotlib.pyplot as plt


points = np.arange(-5, 5, 0.01)

xs, ys = np.meshgrid(points, points)
ys
# Out:
# array([[-5.  , -5.  , -5.  , ..., -5.  , -5.  , -5.  ],
#        [-4.99, -4.99, -4.99, ..., -4.99, -4.99, -4.99],
#        [-4.98, -4.98, -4.98, ..., -4.98, -4.98, -4.98],
#        ...,
#        [ 4.97,  4.97,  4.97, ...,  4.97,  4.97,  4.97],
#        [ 4.98,  4.98,  4.98, ...,  4.98,  4.98,  4.98],
#        [ 4.99,  4.99,  4.99, ...,  4.99,  4.99,  4.99]])

# %%
z = np.sqrt(xs**2 + ys**2)
z
# Out:
# array([[7.07106781, 7.06400028, 7.05693985, ..., 7.04988652, 7.05693985,
#         7.06400028],
#        [7.06400028, 7.05692568, 7.04985815, ..., 7.04279774, 7.04985815,
#         7.05692568],
#        [7.05693985, 7.04985815, 7.04278354, ..., 7.03571603, 7.04278354,
#         7.04985815],
#        ...,
#        [7.04988652, 7.04279774, 7.03571603, ..., 7.0286414 , 7.03571603,
#         7.04279774],
#        [7.05693985, 7.04985815, 7.04278354, ..., 7.03571603, 7.04278354,
#         7.04985815],
#        [7.06400028, 7.05692568, 7.04985815, ..., 7.04279774, 7.04985815,
#         7.05692568]])

# %%
plt.imshow(z, cmap=plt.cm.gray, extent=[-5, 5, -5, 5])

plt.colorbar()
plt.title("Image plot of $\sqrt{x^2 + y^2}$ for a grid of values")
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_9931/246841665.py:4: SyntaxWarning: invalid escape sequence '\s'
#   plt.title("Image plot of $\sqrt{x^2 + y^2}$ for a grid of values")
# Text(0.5, 1.0, 'Image plot of $\\sqrt{x^2 + y^2}$ for a grid of values')

# %% [markdown]
# ### Expressing Conditional Logic as Array Operations
#
#
# * Numpy has its own conditioning clauses presented in the packet.
#
# ```python
# numpy.where(condition, [x, y])
# ```
# * condition: An array or boolean expression.
#
# * x (optional): The value or array to return where the condition is True.
#
# * y (optional): The value or array to return where the condition is False.

# %%
import numpy as np

xarr = np.array([1.1, 1.2, 1.3, 1.4, 1.5])

yarr = np.array([2.1, 2.2, 2.3, 2.4, 2.5])

cond = np.array([True, False, True, True, False])

#we wanted to take a value from xarr whenever the corresponding value in cond is True.

# Python way:
result = [(x if c else y)
          for x, y, c in zip(xarr, yarr, cond)]

result
# Out:
# [np.float64(1.1),
#  np.float64(2.2),
#  np.float64(1.3),
#  np.float64(1.4),
#  np.float64(2.5)]

# %%
# Numpy way:
result = np.where(cond, xarr, yarr)
result
# Out:
# array([1.1, 2.2, 1.3, 1.4, 2.5])

# %%
import numpy as np


rng = np.random.default_rng(seed = 50)

arr = rng.standard_normal((4, 4))
arr
# Out:
# array([[ 4.86381404e-01, -4.77391979e-01,  6.69339620e-01,
#         -1.38729454e+00],
#        [ 1.66588843e+00, -1.90931517e-01,  5.34348860e-01,
#          7.76551786e-01],
#        [ 2.44750368e-01,  1.79810422e-01, -1.34158469e+00,
#         -1.81981247e-01],
#        [-5.42160868e-01,  1.97963483e-03, -2.69980913e+00,
#         -1.55722607e+00]])

# %%
arr > 0
# Out:
# array([[ True, False,  True, False],
#        [ True, False,  True,  True],
#        [ True,  True, False, False],
#        [False,  True, False, False]])

# %%
np.where(arr > 0, 2, -2)
# Out:
# array([[ 2, -2,  2, -2],
#        [ 2, -2,  2,  2],
#        [ 2,  2, -2, -2],
#        [-2,  2, -2, -2]])

# %%
np.where(arr > 0, 2, arr)
# Out:
# array([[ 2.        , -0.47739198,  2.        , -1.38729454],
#        [ 2.        , -0.19093152,  2.        ,  2.        ],
#        [ 2.        ,  2.        , -1.34158469, -0.18198125],
#        [-0.54216087,  2.        , -2.69980913, -1.55722607]])

# %% [markdown]
# ### Mathematical and Statistical Methods
# 1. . Basic Statistical Methods:
#
# These functions allow you to summarize data across an entire array or along a specific axis (e.g., rows or columns).
#
# 2. Extrema and Ordering:
#
# These methods help you find the boundaries of your data or the positions of specific values.
#
# * np.min() / np.max(): Returns the minimum or maximum value.
# * np.argmin() / np.argmax(): Returns the index of the minimum or maximum value
# * np.ptp(): "Peak-to-peak" (Maximum - Minimum).
# * np.percentile(arr, q): Computes the $q^{th}$ percentile of the data.
#
# 3. Mathematical Transformations:
#
# NumPy includes "Universal Functions" (ufuncs) that perform element-wise operations.
#
# * Trigonometry: np.sin(), np.cos(), np.tan()
# * Exponents/Logs: np.exp(), np.log() (natural log), np.log10().
#
# Rounding:
# * np.around(): Rounds to a given number of decimals.
# * np.floor(): Rounds down.
# * np.ceil(): Rounds up.
# 4. Linear Algebra Basics
#
# * np.dot(a, b): Dot product of two arrays.
# * np.matmul(a, b): Matrix multiplication (often used via the @ operator).
# * np.transpose(): Flips the axes of the array (often used as arr.T).
#
# 5. Cumulative Operations
#
# * np.cumsum(): Returns the cumulative sum of elements.
# * np.cumprod(): Returns the cumulative product.
